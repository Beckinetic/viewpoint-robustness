# %%
import pickle

file_path = '../logs/combined_f_combined/resnet18_log_data(1).pkl'
test_path = '../logs/combined_f_combined/resnet18_test_data(1).pkl'
with open(file_path, 'rb') as f:
    result = pickle.load(f)

val_loss = result['vl']
val_acc = result['va']
new_val_loss = {}
new_val_acc = {}

# %%
rekey_list = ['er', 'f', 'r', 'fx', 'cr']
for i, key in enumerate(val_loss):
    new_val_loss[rekey_list[i]] = val_loss[key]
    new_val_acc[rekey_list[i]] = val_acc[key]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 3
#       1 rekey_list = ['er', 'f', 'r', 'fx', 'cr']
#       2 for i, key in enumerate(val_loss):
# ----> 3     new_val_loss[rekey_list[i]] = val_loss[key]
#       4     new_val_acc[rekey_list[i]] = val_acc[key]
#
# IndexError: list index out of range

# %%
test_loss = {}
test_acc = {}

test_loss['cr'] = new_val_loss.pop('cr')
test_acc['cr'] = new_val_acc.pop('cr')

# %%
new_val = {'tl': result['tl'], 'ta': result['ta'], 'vl': new_val_loss, 'va': new_val_acc}
result_test = {'tel': test_loss, 'tea': test_acc}
with open(file_path, 'wb') as f:
    pickle.dump(new_val, f)
with open(test_path, 'wb') as f:
    pickle.dump(result_test, f)
