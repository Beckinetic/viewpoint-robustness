# %%
from src.util.categorize import categorize

categorize('../data/grey_fx_f')
# Out:
# Done

# %%
from src.data.create_dataset import create_labels

# %%
create_labels('/Users/luoyifan/Internship-local/Project/data/robustness/f/content')
# Out:
# '/Users/luoyifan/Internship-local/Project/data/robustness/f/content/labels.json'
