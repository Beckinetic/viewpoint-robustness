# %%
from src.util.categorize import categorize

categorize('../data/grey_fx_f')
# Out:
# Done

# %%
from src.data.create_dataset import create_labels

# %%
create_labels('/Users/luoyifan/Internship-local/Project/data/robustness/ood_f_object/content')
create_labels('/Users/luoyifan/Internship-local/Project/data/robustness/ood_f_background/content')
create_labels('/Users/luoyifan/Internship-local/Project/data/robustness/ood_r_object/content')
create_labels('/Users/luoyifan/Internship-local/Project/data/robustness/ood_r_background/content')
create_labels('/Users/luoyifan/Internship-local/Project/data/robustness/ood_fx_object/content')
create_labels('/Users/luoyifan/Internship-local/Project/data/robustness/ood_fx_background/content')
# Out:
# '/Users/luoyifan/Internship-local/Project/data/robustness/ood_fx_background/content/labels.json'
